# %%
import pandas as pd

csur_df = pd.read_csv('input_CSUR.csv')
csur_df.head()
# Out:
#    abs_id                                          abs_sents  abs_sents_num  \
# 0       0  ['Many developments have taken place within da...              7
# 1       1  ['With the explosive growth of the World Wide ...              9
# 2       3  ['Vessel segmentation algorithms are the criti...              7
# 3       4  ['The article aims to introduce computer scien...              6
# 4       5  ['An overview is presented of object-based and...             13
#
#                                           sent_order  \
# 0  ['background_label', 'background_label', 'obje...
# 1  ['background_label', 'background_label', 'back...
# 2  ['background_label', 'background_label', 'meth...
# 3  ['objective_label', 'background_label', 'objec...
# 4  ['background_label', 'background_label', 'meth...
#
#                                     background_sents  background_sent_num  \
# 0  ['Many developments have taken place within da...                    2
# ...
